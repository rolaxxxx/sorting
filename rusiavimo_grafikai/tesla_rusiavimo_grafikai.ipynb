# %%
import pandas as pd
import os
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from IPython.display import display, Math, Latex
import math
# %matplotlib inline

# %%
failai={}
failai["Radix"]=pd.read_csv("/home/rolandas/Desktop/tesla_rezultatai/tesla_radixsort.txt",sep=" ")
failai["Merge"]=pd.read_csv("/home/rolandas/Desktop/tesla_rezultatai/tesla_mergesort.txt", sep=" ")
failai["Stable"]=pd.read_csv("/home/rolandas/Desktop/tesla_rezultatai/tesla_stablesort.txt",sep=" ")
failai["SortSort"]=pd.read_csv("/home/rolandas/Desktop/tesla_rezultatai/tesla_sort.txt",sep=" ")
failai["RadixByKey"]=pd.read_csv("/home/rolandas/Desktop/tesla_rezultatai/tesla_radixsort_by_key.txt",sep=" ")
failai["SortSortByKey"]=pd.read_csv("/home/rolandas/Desktop/tesla_rezultatai/tesla_sortbykey.txt",sep=" ")
failai["StableByKey"]=pd.read_csv("/home/rolandas/Desktop/tesla_rezultatai/tesla_stablesort_by_key.txt",sep=" ")

# %%
plt.figure(figsize=(10,6))
for var in ["Merge","Radix","Stable","SortSort"]:
    plt.plot(failai[var]["N"],failai[var]["TIME"],label=var,linestyle="-",linewidth=3)
for var in ["SortSortByKey","StableByKey", "RadixByKey"]:
    plt.plot(failai[var]["N"],failai[var]["TIME"],label=var,linestyle="--",linewidth=3)
plt.legend()
plt.xlim(0,0.1e8)
plt.ylim(0,0.125)
plt.grid(color='grey', linestyle='-', linewidth=0.5)
plt.xlabel("Number of elements, N")
plt.ylabel("Time, s")
plt.show()


plt.figure(figsize=(10,6))
for var in ["Merge","Radix","Stable","SortSort"]:
    plt.plot(np.log2(failai[var]["N"]),(failai[var]["N"]/failai[var]["TIME"])/1000000.0,label=var,linestyle="-",linewidth=3)
for var in ["SortSortByKey","StableByKey", "RadixByKey"]:
    plt.plot(np.log2(failai[var]["N"]),(failai[var]["N"]/failai[var]["TIME"])/1000000.0,label=var,linestyle="--",linewidth=3)
plt.legend()

#plt.ylim(0,0.125)
plt.grid(color='grey', linestyle='-', linewidth=0.5)
plt.xlabel("Number of elements, lg(N)")
plt.ylabel("Millions per second, M/s")
plt.show()

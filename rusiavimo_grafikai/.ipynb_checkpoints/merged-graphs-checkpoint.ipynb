# %%
import pandas as pd
import os
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from IPython.display import display, Math, Latex
import math
# %matplotlib inline

# %%
failai={}
failai["Merge-4790"]=pd.read_csv("../data/4790_mergesort.txt" , sep=" ")
failai["Radix-4790"]=pd.read_csv("../data/4790_radixsort.txt",sep=" ")
failai["Stable-4790"]=pd.read_csv("../data/4790_stablesort.txt",sep=" ")
failai["Counting-4790"]=pd.read_csv("../data/4790_countingsort.txt",sep=" ")
failai["Bitonic-4790"]=pd.read_csv("../data/4790_bitonicsort.txt",sep=" ")
failai["RadixByKey-4790"]=pd.read_csv("../data/4790_radix_by_key.txt" , sep=" ")
failai["StableByKey-4790"]=pd.read_csv("../data/4790_stablesort_by_key.txt",sep=" ")


failai["Merge-6700"]=pd.read_csv("../data/6700_mergesort.txt" , sep=" ")
failai["Radix-6700"]=pd.read_csv("../data/6700_radixsort.txt",sep=" ")
failai["Stable-6700"]=pd.read_csv("../data/6700_stableSort.txt",sep=" ")
failai["Counting-6700"]=pd.read_csv("../data/6700_countingsort.txt",sep=" ")
failai["Bitonic-6700"]=pd.read_csv("../data/6700_bitonicsort.txt",sep=" ")
failai["RadixByKey-6700"]=pd.read_csv("../data/6700_radixSort_by_key_element.txt" , sep=" ")
failai["StableByKey-6700"]=pd.read_csv("../data/6700_stablesort_by_element.txt",sep=" ")


failai["Merge-P100"]=pd.read_csv("../data/P100_mergesort.txt" , sep=" ")
failai["Radix-P100"]=pd.read_csv("../data/P100_radixsort.txt",sep=" ")
failai["Stable-P100"]=pd.read_csv("../data/P100_stablesort.txt",sep=" ")
failai["Counting-P100"]=pd.read_csv("../data/P100_countingsort.txt",sep=" ")
failai["Bitonic-P100"]=pd.read_csv("../data/P100_bitonicsort.txt",sep=" ")
failai["RadixByKey-P100"]=pd.read_csv("../data/P100_radix_by_key.txt" , sep=" ")
failai["StableByKey-P100"]=pd.read_csv("../data/P100_stablesort_by_key.txt",sep=" ")


failai["Merge-quadro"]=pd.read_csv("../data/quadro_mergesort.txt" , sep=" ")
failai["Radix-quadro"]=pd.read_csv("../data/quadro_radixsort.txt",sep=" ")
failai["Stable-quadro"]=pd.read_csv("../data/quadro_stablesort.txt",sep=" ")
failai["Counting-quadro"]=pd.read_csv("../data/quadro_countingsort.txt",sep=" ")
failai["Bitonic-quadro"]=pd.read_csv("../data/quadro_bitonicsort.txt",sep=" ")
failai["RadixByKey-quadro"]=pd.read_csv("../data/quadro_radix_by_key.txt" , sep=" ")
failai["StableByKey-quadro"]=pd.read_csv("../data/quadro_stablesort_by_key.txt",sep=" ")


failai["Merge-xeon"]=pd.read_csv("../data/xeon_mergesort.txt" , sep=" ")
failai["Radix-xeon"]=pd.read_csv("../data/xeon_radixsort.txt",sep=" ")
failai["Stable-xeon"]=pd.read_csv("../data/xeon_stablesort.txt",sep=" ")
failai["Counting-xeon"]=pd.read_csv("../data/xeon_countingsort.txt",sep=" ")
failai["Bitonic-xeon"]=pd.read_csv("../data/xeon_bitonicsort.txt",sep=" ")
failai["RadixByKey-xeon"]=pd.read_csv("../data/xeon_radixsort_by_key.txt" , sep=" ")
failai["StableByKey-xeon"]=pd.read_csv("../data/xeon_stablesort_by_key.txt",sep=" ")

# %%
#architekturu lyginimas
plt.figure(figsize=(16,5))
for var in ["Merge-4790","Merge-6700","Merge-P100","Merge-quadro", "Merge-xeon"]:
    plt.plot(failai[var]["N"],failai[var]["TIME"],label=var,linestyle="-",linewidth=3)
plt.legend()
plt.xlim(0,0.1e8)
plt.ylim(0,3)
plt.grid(color='grey', linestyle='-', linewidth=0.5)
plt.xlabel("Number of elements, N")
plt.ylabel("Time, s")
plt.show()


plt.figure(figsize=(16,5))
for var in ["Radix-4790","Radix-6700","Radix-P100","Radix-quadro", "Radix-xeon"]:
    plt.plot(failai[var]["N"],failai[var]["TIME"],label=var,linestyle="-",linewidth=3)
plt.legend()
plt.xlim(0,0.1e8)
plt.ylim(0,3)
plt.grid(color='grey', linestyle='-', linewidth=0.5)
plt.xlabel("Number of elements, N")
plt.ylabel("Time, s")

plt.show()

plt.figure(figsize=(16,5))
for var in ["Stable-4790","Stable-6700","Stable-P100","Stable-quadro", "Stable-xeon"]:
    plt.plot(failai[var]["N"],failai[var]["TIME"],label=var,linestyle="-",linewidth=3)
plt.legend()
plt.xlim(0,0.1e8)
plt.ylim(0,3)
plt.grid(color='grey', linestyle='-', linewidth=0.5)
plt.xlabel("Number of elements, N")
plt.ylabel("Time, s")
plt.show()


plt.figure(figsize=(16,5))
for var in ["Counting-4790","Counting-6700","Counting-P100","Counting-quadro", "Counting-xeon"]:
    plt.plot(failai[var]["N"],failai[var]["TIME"],label=var,linestyle="-",linewidth=3)
plt.legend()
plt.xlim(0,0.1e8)
plt.ylim(0,3)
plt.grid(color='grey', linestyle='-', linewidth=0.5)
plt.xlabel("Number of elements, N")
plt.ylabel("Time, s")
#plt.subplot(2, 3, 2)
plt.show()

plt.figure(figsize=(16,5))
for var in ["Bitonic-4790","Bitonic-6700","Bitonic-P100","Bitonic-quadro", "Bitonic-xeon"]:
    plt.plot(failai[var]["N"],failai[var]["TIME"],label=var,linestyle="-",linewidth=3)
plt.legend()
plt.xlim(0,0.1e8)
plt.ylim(0,3)
plt.grid(color='grey', linestyle='-', linewidth=0.5)
plt.xlabel("Number of elements, N")
plt.ylabel("Time, s")
#plt.subplot(2, 3, 2)
plt.show()

plt.figure(figsize=(16,5))
for var in ["RadixByKey-4790","RadixByKey-6700","RadixByKey-P100","RadixByKey-quadro", "RadixByKey-xeon"]:
    plt.plot(failai[var]["N"],failai[var]["TIME"],label=var,linestyle="-",linewidth=3)
plt.legend()
plt.xlim(0,0.1e8)
plt.ylim(0,3)
plt.grid(color='grey', linestyle='-', linewidth=0.5)
plt.xlabel("Number of elements, N")
plt.ylabel("Time, s")
#plt.subplot(2, 3, 2)
plt.show()


plt.figure(figsize=(16,5))
for var in ["StableByKey-4790","StableByKey-6700","StableByKey-P100","StableByKey-quadro", "StableByKey-xeon"]:
    plt.plot(failai[var]["N"],failai[var]["TIME"],label=var,linestyle="-",linewidth=3)
plt.legend()
plt.xlim(0,0.1e8)
plt.ylim(0,3)
plt.grid(color='grey', linestyle='-', linewidth=0.5)
plt.xlabel("Number of elements, N")
plt.ylabel("Time, s")
#plt.subplot(5, 2, 9)
plt.show()



#sortu lyginimas
plt.figure(figsize=(16,5))
for var in ["Merge-4790","Radix-4790","Stable-4790", "Counting-4790", "Bitonic-4790"]:
    plt.plot(failai[var]["N"],failai[var]["TIME"],label=var,linestyle="-",linewidth=3)
for var in ["StableByKey-4790", "RadixByKey-4790"]:
    plt.plot(failai[var]["N"],failai[var]["TIME"],label=var,linestyle="--",linewidth=3)
plt.legend()
plt.xlim(0,0.1e8)
plt.ylim(0,3)
plt.grid(color='grey', linestyle='-', linewidth=0.5)
plt.xlabel("Number of elements, N")
plt.ylabel("Time, s")
plt.show()

plt.figure(figsize=(16,5))
for var in ["Merge-6700","Radix-6700","Stable-6700", "Counting-6700", "Bitonic-6700"]:
    plt.plot(failai[var]["N"],failai[var]["TIME"],label=var,linestyle="-",linewidth=3)
for var in ["StableByKey-6700", "RadixByKey-6700"]:
    plt.plot(failai[var]["N"],failai[var]["TIME"],label=var,linestyle="--",linewidth=3)
plt.legend()
plt.xlim(0,0.1e8)
plt.ylim(0,3)
plt.grid(color='grey', linestyle='-', linewidth=0.5)
plt.xlabel("Number of elements, N")
plt.ylabel("Time, s")
plt.show()

plt.figure(figsize=(16,5))
for var in ["Merge-P100","Radix-P100","Stable-P100", "Counting-P100", "Bitonic-P100"]:
    plt.plot(failai[var]["N"],failai[var]["TIME"],label=var,linestyle="-",linewidth=3)
for var in ["StableByKey-P100", "RadixByKey-P100"]:
    plt.plot(failai[var]["N"],failai[var]["TIME"],label=var,linestyle="--",linewidth=3)
plt.legend()
plt.xlim(0,0.1e8)
plt.ylim(0,3)
plt.grid(color='grey', linestyle='-', linewidth=0.5)
plt.xlabel("Number of elements, N")
plt.ylabel("Time, s")
plt.show()

plt.figure(figsize=(16,5))
for var in ["Merge-quadro","Radix-quadro","Stable-quadro", "Counting-quadro", "Bitonic-quadro"]:
    plt.plot(failai[var]["N"],failai[var]["TIME"],label=var,linestyle="-",linewidth=3)
for var in ["StableByKey-quadro", "RadixByKey-quadro"]:
    plt.plot(failai[var]["N"],failai[var]["TIME"],label=var,linestyle="--",linewidth=3)
plt.legend()
plt.xlim(0,0.1e8)
plt.ylim(0,3)
plt.grid(color='grey', linestyle='-', linewidth=0.5)
plt.xlabel("Number of elements, N")
plt.ylabel("Time, s")
plt.show()

plt.figure(figsize=(16,5))
for var in ["Merge-xeon","Radix-xeon","Stable-xeon", "Counting-xeon", "Bitonic-xeon"]:
    plt.plot(failai[var]["N"],failai[var]["TIME"],label=var,linestyle="-",linewidth=3)
for var in ["StableByKey-xeon", "RadixByKey-xeon"]:
    plt.plot(failai[var]["N"],failai[var]["TIME"],label=var,linestyle="--",linewidth=3)
plt.legend()
plt.xlim(0,0.1e8)
plt.ylim(0,3)
plt.grid(color='grey', linestyle='-', linewidth=0.5)
plt.xlabel("Number of elements, N")
plt.ylabel("Time, s")
plt.show()


#plt.figure(figsize=(10,6))
#for var in ["Merge-4790","Radix-4790","Stable-4790","SortSort-4790","Counting-4790", "Bitonic-4790"]:
  #  plt.plot(np.log2(failai[var]["N"]),(failai[var]["N"]/failai[var]["TIME"])/1000000.0,label=var,linestyle="-",linewidth=3)
#for var in ["SortSortByKey-4790","StableByKey-4790", "RadixByKey-4790"]:
#    plt.plot(np.log2(failai[var]["N"]),(failai[var]["N"]/failai[var]["TIME"])/1000000.0,label=var,linestyle="--",linewidth=3)
#plt.legend()

#plt.ylim(0,0.125)
#plt.grid(color='grey', linestyle='-', linewidth=0.5)
#plt.xlabel("Number of elements, lg(N)")
#plt.ylabel("Millions per second, M/s")
#plt.show()
